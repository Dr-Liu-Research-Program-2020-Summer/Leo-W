# %%
import glob
import pandas as pd
import numpy as np
from Anomaly import *
from Spearman_Correlation import *

# %%
#for i in range(len(filenames)):
    #CAnomaly(i,'Discharge Air Temperature','Zone Temperature','OutlierR'+str(i+1)+'.csv', graphing=True)

# %%
#Correlation_Dataframe('Correlation_Table.csv')

# %%
correlation_table = pd.read_csv('./Correlation_Table.csv')
correlation_table.head()
# Out:
#         ADP      ADAT       AZT       AAS     AHWVC     DPDAT      DPZT  \
# 0  0.348809 -0.265350  0.085731  0.000000 -0.242696  0.120108 -0.017871
# 1  0.055891 -0.594218 -0.079353  0.000000 -0.451086  0.035154 -0.047802
# 2 -0.269379 -0.229204  0.148983 -0.092986 -0.214506  0.081661  0.037359
# 3  0.419015 -0.637985  0.077233  0.000000 -0.571755 -0.156820  0.059859
# 4  0.088359 -0.259670  0.096919  0.000000 -0.184391  0.460314  0.055561
#
#        DPAS    DPHWVC     DATZT     DATAS   DATHWVC      ZTAS    ZTHWVC  \
# 0  0.000000 -0.114554  0.109033  0.000000  0.570181  0.000000 -0.503413
# 1  0.000000  0.049816  0.092218  0.000000  0.731711  0.000000 -0.274590
# 2 -0.064985 -0.004417  0.113147  0.029566  0.791008  0.064697 -0.302302
# 3  0.000000 -0.194801  0.103141  0.000000  0.911289  0.000000 -0.155035
# 4  0.000000  0.103038  0.237554  0.000000  0.103022  0.000000 -0.612671
#
#      ASHWVC
# 0  0.000000
# 1  0.000000
# 2 -0.015735
# 3  0.000000
# 4  0.000000

# %%
summary = correlation_table.describe()
print(summary)
# Out:
#               ADP        ADAT         AZT         AAS       AHWVC       DPDAT  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.364327   -0.117059   -0.016854    0.252105    0.020670   -0.011248
# std      0.324390    0.212766    0.287292    0.326587    0.296528    0.231993
# min     -0.269379   -0.637985   -0.669292   -0.144782   -0.571830   -0.473874
# 25%      0.128773   -0.261610   -0.196031    0.057884   -0.157410   -0.158155
# 50%      0.322239   -0.131034   -0.035611    0.082863   -0.003922   -0.017013
# 75%      0.604651   -0.006686    0.129619    0.440337    0.098116    0.146793
# max      0.954157    0.502168    0.835807    0.967252    0.815245    0.577908
#
#              DPZT        DPAS      DPHWVC       DATZT       DATAS     DATHWVC  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    -0.042067    0.271492    0.038922    0.170635    0.002429    0.515694
# ...

# %%
for i in correlation_table:
    IFo(correlation_table,i)
# Out:
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# ...
