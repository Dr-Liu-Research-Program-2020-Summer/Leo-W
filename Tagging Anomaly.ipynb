# %%
import glob
import pandas as pd
import numpy as np
from Anomaly import *
from tag import *

# %%
TOP = pd.read_csv('./P.csv')
tag_anomaly(TOP)
# Out:
# ADP Anomalies exist in file index:
# [0, 3, 4, 6, 20, 24, 72, 82, 83]
# DPAS Anomalies exist in file index:
# [0, 1, 2, 3, 4, 5, 6, 16, 20, 66, 82, 97, 98]
# DATHWVC Anomalies exist in file index:
# [0, 1, 2, 3, 4, 5, 6, 16, 20, 66, 82, 97, 98]
#     ADP      ADAT       AZT       AAS     AHWVC     DPDAT      DPZT  DPAS  \
# 0   0.0 -0.099807 -0.106836  0.000000  0.095935  0.038198  0.033769   0.0
# 1   1.0 -0.075870 -0.062053  0.000000 -0.001796  0.028250 -0.049115   0.0
# 2   1.0 -0.065959 -0.021011 -0.982514 -0.041198  0.024256  0.021769   0.0
# 3   0.0 -0.060630 -0.047782  0.000000 -0.015435 -0.065195  0.078076   0.0
# 4   0.0 -0.135956 -0.084090  0.000000  0.101432  0.116413  0.115890   0.0
# ..  ...       ...       ...       ...       ...       ...       ...   ...
# 95  1.0 -0.092297 -0.021290  0.480386 -0.027598 -0.121900  0.111938   1.0
# 96  1.0 -0.408265  0.480185  0.321872  0.141873 -0.227605  0.393080   1.0
# ...

# %%
filenames = glob.glob('./Data/*.csv')
dataframes = [pd.read_csv(f) for f in filenames]

# %%
for i in [0, 3, 4, 6, 20, 24, 72, 82, 83]:
    CAnomaly(dataframes[i],'AirFlow','Damper Position','OutlierR'+str(i+1)+'.csv',i, graphing=True)
# Out:
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# For Room 1 OUTLIERS :  87 INLIERS :  1642 Isolation Forest
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# For Room 4 OUTLIERS :  87 INLIERS :  1642 Isolation Forest
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# ...

# %%
for i in [0, 1, 2, 3, 4, 5, 6, 16, 20, 66, 82, 97, 98]:
    CAnomaly(dataframes[i],'Damper Position','Airflow Setpoint','OutlierR'+str(i+1)+'.csv',i, graphing=False)
# Out:
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# For Room 1 OUTLIERS :  8 INLIERS :  1721 Isolation Forest
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# For Room 2 OUTLIERS :  5 INLIERS :  1724 Isolation Forest
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# ...

# %%
for i in [0, 1, 2, 3, 4, 5, 6, 16, 20, 66, 82, 97, 98]:
    CAnomaly(dataframes[i],'Discharge Air Temperature','Hot Water Valve Command ','OutlierR'+str(i+1)+'.csv',i, graphing=False)
# Out:
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# For Room 1 OUTLIERS :  87 INLIERS :  1642 Isolation Forest
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# For Room 2 OUTLIERS :  87 INLIERS :  1642 Isolation Forest
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# ...
