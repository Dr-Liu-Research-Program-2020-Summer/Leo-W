# %%
import glob
import pandas as pd
import numpy as np
from Anomaly import *
from Spearman_Correlation import *
from Pearson_Correlation import *

# %%
#for i in range(len(filenames)):
    #CAnomaly(i,'Discharge Air Temperature','Zone Temperature','OutlierR'+str(i+1)+'.csv', graphing=True)

# %%
#Pearson_Dataframe('Correlation_Table_P.csv')

# %%
correlation_table_s = pd.read_csv('./Correlation_Table_S.csv')
correlation_table_s.head()
# Out:
#         ADP      ADAT       AZT       AAS     AHWVC     DPDAT      DPZT  \
# 0 -0.269379 -0.229204  0.148983 -0.092986 -0.214506  0.081661  0.037359
# 1  0.482762  0.024904  0.059860  0.071441 -0.007844 -0.007922 -0.090677
# 2  0.023644 -0.368722  0.188211  0.101257 -0.289488 -0.093226  0.101586
# 3  0.562518 -0.289842  0.835807  0.830120  0.058499 -0.166062  0.399987
# 4  0.274303 -0.385148  0.307505  0.207648 -0.470176  0.005618  0.045207
#
#        DPAS    DPHWVC     DATZT     DATAS   DATHWVC      ZTAS    ZTHWVC  \
# 0 -0.064985 -0.004417  0.113147  0.029566  0.791008  0.064697 -0.302302
# 1  0.029587  0.098507 -0.179089  0.019572  0.597787  0.227630 -0.700593
# 2  0.098083  0.009669 -0.239476 -0.042595  0.571957  0.144423 -0.640518
# 3  0.553729  0.058855 -0.178958 -0.117909 -0.000266  0.883317  0.013670
# 4  0.208673  0.117150 -0.183952 -0.020141  0.535594  0.277680 -0.674642
#
#      ASHWVC
# 0 -0.015735
# 1 -0.149492
# 2 -0.106666
# 3  0.061482
# 4 -0.163243

# %%
correlation_table_s.describe()
# Out:
#              ADP       ADAT        AZT        AAS      AHWVC      DPDAT  \
# count  91.000000  91.000000  91.000000  91.000000  91.000000  91.000000
# mean    0.357520  -0.101521  -0.032760   0.257904   0.037502  -0.024422
# std     0.327247   0.201254   0.288691   0.323410   0.280179   0.229377
# min    -0.269379  -0.518547  -0.669292  -0.144782  -0.571830  -0.473874
# 25%     0.126205  -0.239937  -0.203906   0.058721  -0.114573  -0.164111
# 50%     0.301334  -0.116832  -0.058210   0.082924   0.020373  -0.030754
# 75%     0.595876  -0.005898   0.124037   0.440938   0.123286   0.140507
# max     0.954157   0.502168   0.835807   0.967252   0.815245   0.577908
#
#             DPZT       DPAS     DPHWVC      DATZT      DATAS    DATHWVC  \
# count  91.000000  91.000000  91.000000  91.000000  91.000000  91.000000
# mean   -0.055789   0.278682   0.029768   0.178884  -0.001325   0.520873
# std     0.308458   0.307535   0.319193   0.290808   0.209311   0.347909
# ...

# %%
for i in correlation_table_s:
    IFo(correlation_table_s,i)
# Out:
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# ...

# %%
correlation_table_p = pd.read_csv('./Correlation_Table_P.csv')
correlation_table_p.head()
# Out:
#         ADP      ADAT       AZT       AAS     AHWVC     DPDAT      DPZT  \
# 0  0.474654 -0.065959 -0.021011 -0.982514 -0.041198  0.024256  0.021769
# 1  0.344687 -0.026708 -0.000687 -0.447197  0.033736  0.010982  0.129484
# 2  0.454506 -0.184145  0.110745  0.507437 -0.008297 -0.115493  0.177806
# 3  0.718313 -0.196208  0.463997  0.665103  0.305776 -0.134889  0.209117
# 4  0.761467 -0.179722  0.180507  0.542014 -0.092250 -0.023134  0.113460
#
#        DPAS    DPHWVC     DATZT     DATAS   DATHWVC      ZTAS    ZTHWVC  \
# 0 -0.533476 -0.044587  0.042818  0.031698  0.726498  0.046086 -0.428816
# 1  0.582494 -0.010450 -0.187918  0.012596  0.700470  0.229565 -0.592975
# 2  0.566061  0.053363 -0.259851 -0.101116  0.753871  0.138716 -0.524613
# 3  0.701631  0.487737 -0.177662 -0.137714  0.005575  0.674127  0.016216
# 4  0.812589  0.138019 -0.243623 -0.043589  0.663712  0.300937 -0.526585
#
#      ASHWVC
# 0  0.004214
# 1 -0.086099
# 2  0.017584
# 3  0.346755
# 4 -0.001092

# %%
correlation_table_p.describe()
# Out:
#              ADP       ADAT        AZT        AAS      AHWVC      DPDAT  \
# count  91.000000  91.000000  91.000000  91.000000  91.000000  91.000000
# mean    0.663140  -0.071226  -0.070221   0.453106   0.127639  -0.033589
# std     0.238464   0.205104   0.270514   0.420655   0.277603   0.198375
# min    -0.169564  -0.487857  -0.709652  -0.982514  -0.494790  -0.452554
# 25%     0.510684  -0.179345  -0.123457   0.294462  -0.013580  -0.129500
# 50%     0.710542  -0.077540  -0.049541   0.510329   0.082525  -0.055252
# 75%     0.854218   0.004529   0.033693   0.749097   0.235416   0.016990
# max     0.991375   0.699316   0.606796   0.987681   0.930498   0.661206
#
#             DPZT       DPAS     DPHWVC      DATZT      DATAS    DATHWVC  \
# count  91.000000  91.000000  91.000000  91.000000  91.000000  91.000000
# mean   -0.058644   0.722286   0.152739   0.174837  -0.030228   0.587369
# std     0.279345   0.238389   0.330302   0.334874   0.190601   0.339130
# ...

# %%
for i in correlation_table_p:
    IFo(correlation_table_p,i)
# Out:
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# D:\Softwares\Python\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# ...
